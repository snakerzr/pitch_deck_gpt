# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv('.env')) # загружаем open_ai_key
# open

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.prompts.chat import SystemMessage, HumanMessage, HumanMessagePromptTemplate
from langchain.chains import SimpleSequentialChain, SequentialChain
from langchain.chains import LLMChain

# %%
from typing import Any, List, Mapping, Optional

from langchain.callbacks.manager import CallbackManagerForLLMRun
from langchain.llms.base import LLM

from langchain.prompts.prompt import PromptTemplate
from langchain.prompts import ChatPromptTemplate

from langchain.chains import ConversationChain
from langchain.chains import SimpleSequentialChain
from langchain.chains import SequentialChain
from langchain.chains import LLMChain

from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser

from langchain.memory import (
    ChatMessageHistory,
    ConversationBufferMemory,
    ConversationBufferWindowMemory,
    ConversationSummaryBufferMemory
)

# %%
model='gpt-3.5-turbo'
# model='gpt-4' # дорогая для использования

# %%
chat = ChatOpenAI(temperature=0.0, model=model)
# chat

# %% [markdown]
# Описание решения:
#
# Мы представляем уникальную веб-платформу, предназначенную для облегчения процесса создания презентаций для стартапов и проектов. Наш инновационный подход позволяет пользователям создавать впечатляющие презентации при помощи AI, следуя простым инструкциям, которые мы предоставляем.
#
# Автоматическое создание презентации: Пользователь описывает свой стартап, предоставляя необходимую информацию в специально разработанной форме. После этого система генерирует готовую презентацию, автоматически структурируя информацию на слайды. В документе к презентации также включена подробная инструкция о том, как можно настроить и дополнить презентацию на нашей платформе.
#
#
# Технические особенности:
#
# Генерация текста для слайдов презентации с использованием Chat GPT:
# Мы оптимизировали процесс создания содержания для слайдов, воспользовавшись передовым инструментом - Chat GPT. Это позволяет нам генерировать качественный и информативный текст, который легко интегрировать в наши презентации.
# Текст для презентации генерируется на основе рекомендаций Y Combinator. Это позволяет нам внедрять передовые стратегии и советы из выдающегося стартап-сообщества.
#
# Уникальный логотип, созданный Dally:
# Генерация логотипа разработана при помощи Dally. Этот инструмент обеспечивает уникальность и запоминаемость брендовой идентичности.
#
# Интуитивная веб-платформа на базе Streamlit:
# Мы выбрали Streamlit как основу для нашей веб-платформы, чтобы обеспечить пользователей максимальной удобством и наглядностью. Это позволяет нам предоставить гладкое и интуитивно понятное взаимодействие с нашим сервисом.
#
# Генерация презентаций с помощью pptx:
# Для создания презентаций мы полагаемся на мощный инструмент pptx. Этот инструментарий обеспечивает точную и креативную визуализацию наших идей, помогая нам донести ключевые сообщения до аудитории.
#
# Что отличает наше решение от аналогов:
#
# Наше решение объединяет множество инструментов и методов для максимально полной автоматизации процесса создания презентаций. Это позволяет сэкономить время и ресурсы, обеспечивая высокое качество и эффективность.
#
# Уникальность - использование рекомендация от Y Combinator:
#
# Мы не только создаем информативные слайды, но и внедряем передовые стратегии и инсайты, предоставленные ведущим стартап-инкубатором. Эта уникальная особенность позволяет нам не просто донести идеи, но и подкрепить их авторитетом и экспертностью Y Combinator.
#
# Как помогает наше решение?:
#
# Мы создали платформу, которая облегчает процесс создания презентаций для тех, кто сталкивается с ограниченным временем или не имеет опыта в этой области. Наша цель - упростить жизнь обычного человека, предоставив ему инструмент, способный в кратчайшие сроки создать презентацию на основе описания проекта.
#
# Мы осознаем, что сроки могут быть критически важными, и не всегда есть возможность потратить драгоценные часы на создание презентации. Наше решение позволяет оперативно получить готовый продукт, при этом минимизируя усилия.
#
# Путем предоставления четких инструкций и легко понимаемых шагов, мы позволяем описать проект, а затем автоматически сформировать на основе этой информации структурированную и информативную презентацию. Это дает возможность представить идею профессионально и убедительно, не отвлекаясь от других важных задач.

# %% [markdown]
# ## Общее описание структуры

# %% [markdown]
# Components of a Startup Idea:
#
# A startup idea consists of three main parts: problem, solution, and insight.
# Founders need to construct a compelling hypothesis about their idea's growth potential.
# Investors want evidence that the company can grow quickly.
# The Problem:
#
# The problem is the initial condition for the startup to grow.
# Good problems are popular, growing, urgent, expensive, mandatory, and frequent.
# Frequency is crucial, allowing opportunities for conversion.
# BJ Fogg's formula for behavior change: motivation, ability, and trigger.
# Startups need to address triggers to gain user engagement and retention.
# Ideal Startup Problems:
#
# Ideal problems have millions of users, grow rapidly, and are urgent.
# Expensive problems with billion-dollar markets are attractive.
# Regulatory changes create opportunities.
# Frequent problems yield more chances for user conversion.
# The Solution:
#
# Avoid "Solution In Search of a Problem" (SISP) approach.
# Don't start with technology; start with a problem to solve.
# Find problems people have and tailor solutions to them.
# The insight explains why the chosen solution will work.
# The Insight:
#
# The insight is the company's unfair advantage.
# An insight explains why the startup will grow faster than competitors.
# Insights can be about the problem, solution, growth channel, or revenue.
# Multiple insights can provide a stronger position for success.
# Startup Idea as a Hypothesis:
#
# A startup idea is a hypothesis about rapid growth.
# Founders must prove this hypothesis true.
# Components of the idea (problem, solution, insight) form a compelling story.
# The story inspires belief from others, including investors.
# Confidence and Iteration:
#
# Confidence in the idea is essential.
# Success comes from iterating on the solution, insight, growth channel, and revenue.
# Confidence and continuous iteration lead to a successful company.

# %% [markdown]
# # Вопрос 2: Описание и ценностное предложение стартапа

# %%
question_prompt = '''Напиши ценностное предложение стартапа из ответа {text} по пунктам.

Учти след. информацию:
<<Если вы строите маркетплейс или платформу, которая может монополизировать рынок, это может быть значительным преимуществом. Важно также удостовериться, что вы сможете укрепить свои позиции с ростом.>>

 
Пример вывода: <<Everytalent - платформа для подбора персонала на базе искусственного интеллекта.
● Подбирает молодых талантов в компании и на рабочие места на основе результатов их оценки
● Мотивирует соискателей рекомендациями по превращению слабых сторон в сильные
● Оценивает и определяет навыки и компетентность лиц, ищущих работу>>


'''

# %%
с3_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(question_prompt)
    )
message_gpt = с3_chain(message)['text']

# %%
gpt_prompt = """У тебя есть текст {text}, по которому будут рассказывать презентацию, тебе нужно сократить этот текст до минимума, чтобы поместить на слайд презентации. Дополнительно есть инструкции к формированию:


# !!<<Фокус на суть
Использование ключевых слов
Акцент на преимуществах
Эмоциональная привлекательность
Избегайте повторений
Сжатость
Зрительная привлекательность>>!!


"""

# %%
с4_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(gpt_prompt)
    )
test = с4_chain(message_gpt)['text']

# %%
print(test)
# Out:
# UnSpot - инновационная система бронирования рабочих мест в офисе. Оптимизируйте расходы на аренду и управляйте подразделениями.
#
# Гибкие рабочие места и аналитика посещаемости.
#
# Снизьте расходы и повысьте привлекательность офиса для сотрудников.
#
# Мы видим значительный потенциал в гибридной форме работы и "коворкинге".
#
# UnSpot - инструмент для оптимизации рабочих пространств и сокращения расходов.

# %% [markdown]
# # Вопрос 3: Команда + Борд

# %%
message = '''Команда TechScribe AI состоит из выдающихся профессионалов с разнообразным опытом в области искусственного интеллекта, лингвистики и разработки программного обеспечения.

Джессика Рейнольдс - сооснователь и CEO. Имеет 10 лет опыта в области машинного обучения и ранее работала в Google Brain над разработкой нейросетей для обработки текста.
Майкл Чен - сооснователь и CTO. Бывший научный сотрудник MIT с обширным опытом в области естественного языка и автоматической обработки текстов.
Эмилия Давидсон - главный разработчик. Имеет опыт в создании инновационных решений для обработки больших объемов текстовых данных и разработке масштабируемых систем.
Бэкграунд:
TechScribe AI был основан с целью революционизировать способ, которым компании анализируют и понимают текстовые данные. Мы разработали уникальную платформу, использующую передовые методы обработки естественного языка и машинного обучения для извлечения ценной информации из больших объемов текста. Наша технология нацелена на улучшение процессов анализа рынка, мониторинга мнений клиентов и автоматизации обработки документов.

Текущие инвесторы:
На данный момент TechScribe AI привлек $5 млн инвестиций в рамках сидингового раунда. Среди наших инвесторов:

Innovate Ventures - венчурный фонд, специализирующийся на поддержке инновационных стартапов в сфере искусственного интеллекта.
TechCapital Partners - инвестиционная компания, фокусирующаяся на технологических стартапах с высоким потенциалом роста.
Эдвайзеры:
Наши эдвайзеры - признанные эксперты в области искусственного интеллекта и предпринимательства:

Др. Лиза Андерсон - профессор компьютерных наук в Университете Стэнфорда, автор множества публикаций в области обработки естественного языка.
Джон Смит - успешный предприниматель, основатель и бывший CEO AI Tech Solutions, компании, специализирующейся на разработке решений на основе искусственного интеллекта.'''

# %%
question_prompt = '''Напиши короткую информацию о команде, бекграунде и текущих инвесторах/эдвайзерах {text} по пунктам.


Пример: 


Вывод : <<Everytalent - платформа для подбора персонала на базе искусственного интеллекта.
● Подбирает молодых талантов в компании и на рабочие места на основе результатов их оценки
● Мотивирует соискателей рекомендациями по превращению слабых сторон в сильные
● Оценивает и определяет навыки и компетентность лиц, ищущих работу>>


'''

# %%
с3_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(question_prompt)
    )
message_gpt = с3_chain(message)['text']

# %%
print(message_gpt)
# Out:
# TechScribe AI - компания, специализирующаяся на обработке текстовых данных с помощью искусственного интеллекта и машинного обучения.
# - Команда состоит из профессионалов с опытом в области искусственного интеллекта, лингвистики и разработки программного обеспечения.
# - Джессика Рейнольдс, сооснователь и CEO, имеет опыт в разработке нейросетей для обработки текста в Google Brain.
# - Майкл Чен, сооснователь и CTO, имеет опыт в области естественного языка и автоматической обработки текстов.
# - Эмилия Давидсон, главный разработчик, имеет опыт в создании инновационных решений для обработки текстовых данных и разработке масштабируемых систем.
# - TechScribe AI разработала уникальную платформу, использующую передовые методы обработки естественного языка и машинного обучения для извлечения информации из больших объемов текста.
# - Технология TechScribe AI направлена на улучшение процессов анализа рынка, мониторинга мнений клиентов и автоматизации обработки документов.
# ...

# %% [markdown]
# # Roadmap

# %%
message = '''Этот организационный план на 4 года. И если говорить о крупных задачах проекта, то хотим выделить следующие. 2022 год: найти госзакупку на 2 миллиона рублей для телеграма, а также собрать данные, на которых сможем обучить нейронную сеть. 2023 год: Найти топ 10 работодателей регионов, с помощью которых сможем получить нужное количество вакансий, с которых получим 2.5 миллиона рублей. Для образования нам нужно получить лицензию, записать курсы, найти обучабщую площадку. Открыть для начала 3 региона (Воронежская, Рязанская и Белгородские области), 2024-25 год Открыть 6 офисов с помощью франшизы.'''

# %%
question_prompt = '''Напиши дорожную карту по описанию {text} по пунктам. Дорожная карта должна представлять себя год и что в этот год будет сделано.

Если человек указал года, то указывай их так, как указал человек.


Пример: 


Вывод : <<Everytalent - платформа для подбора персонала на базе искусственного интеллекта.
● Подбирает молодых талантов в компании и на рабочие места на основе результатов их оценки
● Мотивирует соискателей рекомендациями по превращению слабых сторон в сильные
● Оценивает и определяет навыки и компетентность лиц, ищущих работу>>


'''

# %%
с3_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(question_prompt)
    )
message_gpt = с3_chain(message)['text']

# %%
gpt_prompt = """У тебя есть текст {text}, тебе нужно сократить этот текст до минимума, чтобы поместить на слайд презентации. Дополнительно есть инструкции к формированию:

# !!Не используй текст из инструкций в тексте, который пишешь!!


# !!<<Фокус на суть
Использование ключевых слов
Акцент на преимуществах
Эмоциональная привлекательность
Избегайте повторений
Сжатость
Зрительная привлекательность>>!!


"""

# %%
с4_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(gpt_prompt)
    )
test = с4_chain(message_gpt)['text']

# %%
print(test)
# Out:
# 2022 год:
# - Госзакупка на 2 млн рублей для телеграма
# - Сбор данных для обучения нейронной сети
#
# 2023 год:
# - Топ 10 работодателей регионов
# - Необходимое количество вакансий
# - 2.5 млн рублей
# - Лицензия для образования
# - Курсы и обучающая площадка
# - Открытие офисов в 3 областях
#
# 2024-25 год:
# - Открытие 6 офисов с помощью франшизы

# %%
message = '''Система UnSpot – это программное обеспечение для бронирования, позволяющее сотрудникам временно резервировать для себя любое незакрепленное рабочее место в офисе компании. 

ПО помогает руководителям управлять своими подразделениями более гибко, отслеживать посещаемость работников и снижать расходы на аренду офиса. 

UnSpot позволяет: оптимизировать расходы на аренду офиса; с помощью предоставляемой аналитики понять, как сотрудники используют офис и сделать его более привлекательным для них; вырастить HR-бренд компании.

Преимущества: 
- компания демонстрирует устойчивый рост финансовых показателей;

- компания обладает существенным потенциалом в условиях развития гибридного формата работы, а также обширного распространения офисов типа «коворкинг». 
'''

# %%
classification_prompt = '''Сообщение нужно отнести только к определенному классу:
<<Тебе нужно вывести число!>>

Класс 0 - Бизнес относится к "Энергетика и коммунальные услуги"
Класс 1 - Бизнес относится к "ИТ-услуги"
Класс 2 - Бизнес относится к "ПО"
Класс 3 - Бизнес относится к "Производство промышленного оборудования"
Класс 4 - Бизнес относится к "Финансовый сектор услуг"
Класс 5 - Бизнес относится к "Профессиональные услуги: бухгалтерские, юридические, инженерные и т.д.""
Класс 6 - Бизнес относится к "Телекоммуникации"
Класс 7 - Бизнес относится к "Производство товаров"
Класс 8 - Бизнес относится к "Транспорт и перевозки"
Класс 9 - Бизнес относится к "Производство потребительских товаров"
Класс 10 - Бизнес относится к "Оптовая торговля"

Пример вывода: 1

СООБЩЕНИЕ:<<<{message}>>>
'''

# %%
с1_chain = LLMChain(
        llm=llm,
        prompt=PromptTemplate.from_template(classification_prompt)
    )
try:
    try:
        c1_message_class = с1_chain(message)['text']
    except:
        c1_message_class = с1_chain(message)['text']
except:
    pass

print(c1_message_class)
# Out:
# 1

# %%
churn_rate_by_industry = {'Энергетика и коммунальные услуги':.11,
                          'ИТ-услуги':.12,
                          'ПО':.14,
                          'Производство промышленного оборудования':.17,
                          'Финансовый сектор услуг':.19,
                          'Профессиональные услуги: бухгалтерские, юридические, инженерные и т.д.':.27,
                          'Телекоммуникации':.31,
                          'Производство товаров':.35,
                          'Транспорт и перевозки':.40,
                          'Производство потребительских товаров':.40,
                          'Оптовая торговля':.56}

# %%
revenue = 100000
ammount_clients = 300
APRU = revenue / ammount_clients
churn_rate = list(churn_rate_by_industry.values())[int(c1_message_class)]
LT = 1 / churn_rate
LTV = APRU * LT

# %% [markdown]
# # END

# %% [markdown]
# ## Вопрос 1

# %% [markdown]
# Сначала мы задаем первичную инструкцию для чатагпт, в которой описываем его роль.

# %%
role = '''
Ты превосходный специалист по созданию питч деков. Сейчас ты помогаешь владельцу стартапа написать отличный питч дек.
'''

# %% [markdown]
# Затем мы даем контекст инструкцию для чатгпт.
# В ней мы пишем следующее:

# %%
context = '''Тебе нужно проработать "продукт", "решение" и "инстайт", которые пытается решить стартап.
'''

# %% [markdown]
# А затем детали, которые описывают то, из чего состоит проблема, какую информацию нужно решить.

# %%
details = '''
Несправедливое Преимущество:

- Отношение к Росту: 
Несправедливое преимущество должно быть непосредственно связано с возможностью быстрого роста компании. Это то, что делает вашу компанию привлекательной для инвесторов.

- Необходимость Преимущества: 
Преимущество необходимо, так как оно выделяет вашу компанию из массы и демонстрирует ваш потенциал на рынке. Одно такое преимущество - минимум, но лучше иметь их больше.

Типы Несправедливых Преимуществ:

Уникальные Качества Основателей: 
Если основатели обладают уникальными навыками, опытом или качествами, которые могут существенно влиять на успех компании, это может служить несправедливым преимуществом.

 - Растущий Рынок (10-20%): 
Хотя растущий рынок является слабым преимуществом, оно должно дополняться другими факторами, чтобы выделяться на фоне среднего.

- Супер Продукт: 
Очевидное преимущество - продукт, который значительно лучше конкурентов. Продукт должен быть на порядок (в 10 раз) более привлекательным и эффективным.

- Приобретение Клиентов: 
Обратите внимание на приобретение клиентов через нестандартные каналы, которые развиваются на основе сарафанного радио. Это означает, что ваши пользователи сами распространяют информацию о продукте.

- Монополия: 
Если вы строите маркетплейс или платформу, которая может монополизировать рынок, это может быть значительным преимуществом. Важно также удостовериться, что вы сможете укрепить свои позиции с ростом.

- Важное Замечание: 
Несправедливое преимущество должно быть прямо связано с ростом компании. Инвесторы ищут именно то, что позволит вашему стартапу вырасти быстрее и успешно конкурировать на рынке.'''

# %% [markdown]
# И инструкцию, в которой просим чатгпт собрать необходимое кол-во информации, чтобы выяснить какова проблема
# в соответствии с деталями выше.

# %%
instruction = '''Твоя задача собрать информацию у владельца стартапа о продукте, о решении и об инсайте, которые они предлагают.
И сделать это в таком виде, в котором были бы ясно видны и понятны те характеристики, которые делают продукт, решение и инсайт "хорошими" для инвестора.
'''

# %% [markdown]
# Теперь напишем промпт для первого сообщения, в котором чатгпт прояснит контекст и то, как он будет выяснять детали.

# %%
first_human_message_as_instruction = '''
Привет! Я владелец стартапа. Объясни, что ты хочешь у меня узнать и в каком ключе ты хочешь получаться ответы.'''

# %%
template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content=(role+context+details+instruction)),
        HumanMessagePromptTemplate.from_template(first_human_message_as_instruction),
    ]
)

from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI()
llm(template.format_messages())
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).
# AIMessage(content='Привет! Моя задача - помочь тебе создать отличный питч дек для твоего стартапа. Я хочу узнать о продукте, решении и инсайте, которые ты предлагаешь, чтобы я мог проработать их в таком виде, чтобы было ясно видно, какие характеристики делают их "хорошими" для потенциальных инвесторов. Таким образом, я буду задавать тебе вопросы, чтобы получить максимум информации о твоем продукте, решении и инсайте.', additional_kwargs={}, example=False)

# %%
first_prompt = ChatPromptTemplate.from_template(
    "Translate the following review to english:"
    "\n\n{Review}"
)

# %%
prompt_question = ''' 

Эта информация поясняет то, что представляет из себя хороший сценарий pitch deck: <<Несправедливые преимущества играют ключевую роль в успешном стартапе, предоставляя компании уникальные пути для быстрого роста и конкурентного преимущества на рынке. Они выделяют компанию из множества конкурентов и делают ее более привлекательной для инвесторов, пользователей и партнеров. Иметь хорошо обоснованные несправедливые преимущества с уклоном на рост помогает компании успешно расти, масштабироваться и оставаться конкурентоспособной на долгий срок.>>


Несправедливое Преимущество:

Отношение к Росту: Несправедливое преимущество должно быть непосредственно связано с возможностью быстрого роста компании. Это то, что делает вашу компанию привлекательной для инвесторов.

Необходимость Преимущества: Преимущество необходимо, так как оно выделяет вашу компанию из массы и демонстрирует ваш потенциал на рынке. Одно такое преимущество - минимум, но лучше иметь их больше.

Типы Несправедливых Преимуществ:

Уникальные Качества Основателей: Если основатели обладают уникальными навыками, опытом или качествами, которые могут существенно влиять на успех компании, это может служить несправедливым преимуществом.

Растущий Рынок (10-20%): Хотя растущий рынок является слабым преимуществом, оно должно дополняться другими факторами, чтобы выделяться на фоне среднего.

Супер Продукт: Очевидное преимущество - продукт, который значительно лучше конкурентов. Продукт должен быть на порядок (в 10 раз) более привлекательным и эффективным.

Приобретение Клиентов: Обратите внимание на приобретение клиентов через нестандартные каналы, которые развиваются на основе сарафанного радио. Это означает, что ваши пользователи сами распространяют информацию о продукте.

Монополия: Если вы строите маркетплейс или платформу, которая может монополизировать рынок, это может быть значительным преимуществом. Важно также удостовериться, что вы сможете укрепить свои позиции с ростом.

Важное Замечание: Несправедливое преимущество должно быть прямо связано с ростом компании. Инвесторы ищут именно то, что позволит вашему стартапу вырасти быстрее и успешно конкурировать на рынке.




 Из описания !!<<{text}>>!!, которое тебе написал человек, тебе нужно самому ответить, либо придумать ответы на эти вопросы, даже если описание не очень подробное, не используя слова  или цифры из самого вопроса.
 
 
 
 Необходимо ответить на след. вопросы:
 
 Какие уникальные навыки, опыт или качества у вас и вашей команды, которые могут существенно влиять на успех стартапа?
 Каким образом рост вашего рынка (10-20%) дополняет ваши несправедливые преимущества, чтобы выделять вас среди конкурентов? 
 Пожалуйста, дайте подробное описание, каким образом ваш продукт значительно (в 10 раз) превосходит продукты конкурентов? 
 Что делает его таким эффективным и привлекательным?
 Какие нестандартные каналы приобретения клиентов вы используете?
 Можете ли вы привести примеры, когда пользователи сами распространяли информацию о вашем продукте?
 Если вы строите маркетплейс или платформу, как вы планируете монополизировать рынок? 
 Какие меры предпринимаются для укрепления ваших позиций с ростом компании?
 
 Верни мне json в формате вопрос-ответ.
'''

# %%
test_description = '''У нас есть телеграм-бот, через который можно откликаться на разовые поручения или заявки на временную работу студенты регистрируются там и находятся в ожидании приходящих заявок мы заранее проговариваем с муниципальным предприятием условия гос.закупки на право заключение договора с обязательством предоставления в  течение 12 часов заявленного количества сотрудников, на некоторое количество раз в сезон в день ИКС уходят оповещения по нашей базе самозанятых о возможности выйти на двухдневную работу.
Для того, чтобы студент имел нужные знания, существуют стажировки. На обучение выпускника тратят определенную сумму денег и не факт, что он останется работать. Мы предлагаем, чтобы студент шел к нам, мы его обучали(давали узконаправленные знания для быстрого трудоустройства), после чего отправляем его на работу на определенное время, где он получает опыт. Спустя 3 месяца мы имем хорошего начального спкциалиста,  который спокойно сможет устроиться на работу. С каждой оплаты работу студента мы забираем 10 процентов себе. Мы планируем пойти дальше и получить лицензию на образовательную деятельность, чтобы иметь возможность разрабатывать свои обучающие программы, проработанные с экспертами предприятий (металлургическими комбинатами, операторами связи, заводами, инженерными компаниями), благодаря которым молодой специалист будет проходить "курс молодого бойца" исходя из реальных потребностей производственного сектора. Образование будет платным и укладывается в рамки ожиданий опрошенных нами респондентов.

Наши преимущества - мы сами студенты среднего профессионального учреждения, мы внутри проблемы и мы целевая аудитория.'''

# %%
first_prompt = ChatPromptTemplate.from_template(prompt_question)

# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt)

test_request = chain_one.run(test_description)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).

# %%
print(test_request)
# Out:
# {
#   "Какие уникальные навыки, опыт или качества у вас и вашей команды, которые могут существенно влиять на успех стартапа?": "Мы сами студенты среднего профессионального учреждения и находимся внутри проблемы, что дает нам уникальное понимание потребностей целевой аудитории. Кроме того, у нас есть знания и опыт в области разработки и продвижения технологических решений.",
#   "Каким образом рост вашего рынка (10-20%) дополняет ваши несправедливые преимущества, чтобы выделять вас среди конкурентов?": "Рост рынка позволяет нам увеличивать количество потенциальных клиентов и расширять нашу базу самозанятых, что обеспечивает нам больше возможностей для предоставления временной работы студентам. Это также позволяет нам привлекать больше муниципальных предприятий и заключать долгосрочные договоры с ними.",
# ...

# %%
question_list = ['Какие уникальные навыки, опыт или качества у вас и вашей команды, которые могут существенно влиять на успех стартапа?',
                 'Каким образом рост вашего рынка (10-20%) дополняет ваши несправедливые преимущества, чтобы выделять вас среди конкурентов?', 
                 'Пожалуйста, дайте подробное описание, каким образом ваш продукт значительно (в 10 раз) превосходит продукты конкурентов?', 
                 'Что делает его таким эффективным и привлекательным?'
                 'Какие нестандартные каналы приобретения клиентов вы используете?', 
                 'Можете ли вы привести примеры, когда пользователи сами распространяли информацию о вашем продукте?',
                 'Если вы строите маркетплейс или платформу, как вы планируете монополизировать рынок?', 
                 'Какие меры предпринимаются для укрепления ваших позиций с ростом компании?']
