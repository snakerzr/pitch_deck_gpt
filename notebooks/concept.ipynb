# %% [markdown]
# ## Предварительная архитектура проекта

# %% [markdown]
# * Интерфейс для ввода
# * Бэкенд для обработки и создания инфы
# * Интерфейс для генерации логотипа
# * Интерфейс для генерации стиля слайдов
# * Интерфейс для конечной генерации презентации (pptx Или pdf(лучше))

# %% [markdown]
# ## Ввод

# %% [markdown]
# https://drive.google.com/drive/folders/1FtHPVLEbgSi2_I-_f-nQTTNETwk--bof

# %% [markdown]
# Типы Несправедливых Преимуществ:
#
#
#
#
#
#
#
#
# - Монополия:
# Если вы строите маркетплейс или платформу, которая может монополизировать рынок, это может быть значительным преимуществом. Важно также удостовериться, что вы сможете укрепить свои позиции с ростом.

# %% [markdown]
# ### Название

# %% [markdown]
# Минимум:
# * Название вводит стартапер.
# * Краткое описание вводит стартапер (Одним предложением описание проекта / ключевая ценность)
# * ЧатГПТ переформулирует краткое описание на соответсвие принципам Y comb
#
# Дополнительно:
# * ГПТ генерирует названия по описанию

# %% [markdown]
# ### Проблема

# %% [markdown]
# Описание проблемы, которую решает проект, целевая аудитория (самостоятельно либо генерируется)

# %% [markdown]
# Минимум:
# * Проблема описывается стартапером настолько подробно, насколько он может
# * ЧатГПТ переформулирует YComb
#
# Дополнительно:
# * Проработать проблему со стартапером с помощью чатгпт в виде интерактинвого диалога

# %% [markdown]
# ### Описание и ценностное предложение стартапа

# %% [markdown]
# (вводится самостоятельно)

# %% [markdown]
# Я пока до сих пор не понимаю о чем речь? Если в решении мы говорим про несправедливые преимущества.

# %% [markdown]
# Монополия:
# Если вы строите маркетплейс или платформу, которая может монополизировать рынок, это может быть значительным преимуществом. Важно также удостовериться, что вы сможете укрепить свои позиции с ростом.

# %% [markdown]
# ### Решение

# %% [markdown]
# Описание функционала продукта, как помогает закрыть потребности потенциального клиента(самостоятельно)

# %% [markdown]
# Минимум:
# * Стартапер вводит описание функционала
# * ЧатГПТ переформулирует YComb (unfair advantages)
#
# Дополнительно:
# * Загрузить скриншот продукта (зачем?)

# %% [markdown]
# Возможно 2 слайда (?):
# 1. Описание функционала
# 2. YComb unfair advantages

# %% [markdown]
# Супер Продукт:
# Очевидное преимущество - продукт, который значительно лучше конкурентов. Продукт должен быть на порядок (в 10 раз) более привлекательным и эффективным.

# %% [markdown]
# ### Рынок (Размер рынка)

# %% [markdown]
# Размер рынка. TAM - SAM - SOM

# %% [markdown]
# Нужно по описанию решения и любой какой-то вводимой стартапером инфы определить вот эти TAM, SAM, SOM
#
# Это выглядит объемно и сложно, но кажется, что очень важно. Было бы круто это автоматизировать.
#
# https://productframework.ru/tam_sam_som
# https://vc.ru/money/159115-ocenit-rynok-startapa-za-polchasa-metod-tam-sam-som
# https://docs.google.com/document/d/14-DcHvI34Oi7Ed6BE8UD1Ze6LhjXMwdp/edit

# %% [markdown]
# Минимум:
# * Самостоятельно клиент вводит инфу
# * ЧатГПТ преобразовывает
#
# Дополнительно:
# * ГПТ4 занимается сбором и анализом инфы

# %% [markdown]
# Растущий Рынок (10-20%):
# Хотя растущий рынок является слабым преимуществом, оно должно дополняться другими факторами, чтобы выделяться на фоне среднего.

# %% [markdown]
# ### Конкуренты

# %% [markdown]
# (текущие конкуренты, ключевые конкурентные преимущества)(найти самостоятельно)

# %% [markdown]
# Конкурентов проекта можно найти через такие
# информационные источники как Sbis, Чекко, TadViser и
# другие доступные источник
# https://sbis.ru/
# https://checko.ru/
# https://www.tadviser.ru/и.

# %% [markdown]
# Минимум:
# * Найти конкуренто в предоставленном документе
# * Попросить ГПТ сгенерировать конкурентные преимущества
#
# Дополнительно:
# * ГПТ4 находит конкурентов в интернете
# * Он же проводит анализ

# %% [markdown]
# Супер Продукт:
# Очевидное преимущество - продукт, который значительно лучше конкурентов. Продукт должен быть на порядок (в 10 раз) более привлекательным и эффективным.

# %% [markdown]
# ### Бизнес-модель и ценообразование

# %% [markdown]
# **Очень широкая постановка вопроса. Что именно тут нужно? Откуда брать? Генерировать?**

# %% [markdown]
# Бизнес-модель стартапа, тарифы, условия для клиентов

# %% [markdown]
# (что стартапер вводит?) Вводится стартапом.

# %% [markdown]
# https://drive.google.com/drive/folders/1k5rKoBqz685ZF5hgTx7YUyLLJjgMwOGT

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу
# * ГПТ причесывает
#
# Дополнительно:
# * ГПТ4 ищет на сайте компании
# * ИЛИ ГПТ4 генеририрует вариант

# %% [markdown]
# Приобретение Клиентов:
# Обратите внимание на приобретение клиентов через нестандартные каналы, которые развиваются на основе сарафанного радио. Это означает, что ваши пользователи сами распространяют информацию о продукте.

# %% [markdown]
# ### Трекшн и финансы

# %% [markdown]
# (Трекшн, партнерства, выручка, кол-во клиентов, CAC - LTV)

# %% [markdown]
# https://drive.google.com/drive/folders/1k5rKoBqz685ZF5hgTx7YUyLLJjgMwOGT

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу какую-то
# * ГПТ причесывает
#
# Дополнительно:
# * ГПТ4 ищет на сайте компании
# * ИЛИ ГПТ4 генеририрует вариант

# %% [markdown]
# Приобретение Клиентов:
# Обратите внимание на приобретение клиентов через нестандартные каналы, которые развиваются на основе сарафанного радио. Это означает, что ваши пользователи сами распространяют информацию о продукте.

# %% [markdown]
# ### Команда + Борд

# %% [markdown]
# (Команда проекта + бекграунд; текущие инвесторы эдвайзеры) (Самостоятельный ввод)

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу
# * ГПТ причесывает
#
# Дополнительно:
# * ГПТ общается со стартапером объясняя че к чему по принципам YComb

# %% [markdown]
# Уникальные Качества Основателей:
# Если основатели обладают уникальными навыками, опытом или качествами, которые могут существенно влиять на успех компании, это может служить несправедливым преимуществом.

# %% [markdown]
# ### Инвестиционный раунд

# %% [markdown]
# (Объем необходимых инвестиций, куда будут направлены средства) (самостоятельный ввод)

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу
# * ГПТ причесывает

# %% [markdown]
# ### Roadmap

# %% [markdown]
# (цели проекта, дедлайны) (самостоятельный ввод)

# %% [markdown]
# Стартапер вводит в виде
# 1.
# 2.
# 3. или как то еще
#
# А гпт генерирует картинку или код для картинки

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу
# * ГПТ генерирует
# * Стартапер проверяет

# %% [markdown]
# ### Контактная информация

# %% [markdown]
# (самостоятельный ввод)

# %% [markdown]
# Минимум:
# * Стартапер вводит инфу
# * ГПТ причесывает

# %% [markdown]
# ## Вопросы

# %% [markdown]
# 1. Можем ли мы изменить шаблон? Или строго по примеру?
# 2. Чем отличается "Описание и ценностное предложение стартапа" и Решение? Кажется, что там может дублироваться информация или это можно совместить в один слайд
# 3. Можно поменять местами решение и ценностное предложение стартапа? Сначала что делаем, а потом почему будет успех
# 4. Что подразумевается под парсером? ОБработчик ввода текста стартапера или парсерс сайтов? Можно ли без парсера?
# 5. Можете ли рассказать, что ожидается увидеть в трекшне и финансах.
# 6. Про инвестиционный раунд. Есть какая-то типология или в сущности здесь стартапер рассказывает куда ему нужны деньги для развития?

# %% [markdown]
# ## Бэкенд для обработки и создания инфы (содержания)

# %% [markdown]
# Минимум:
# * ГПТ
#     * переформулирует проблему with YComb
#     * обрабатывается "Описание и ценностное предложение стартапа" пока не понимаю как
#     * переформулирует решение (unfair advantages) with YComb
#     * причесывает ввод инфы про рынок
#     * генерирует конкурентные преимущества по вводу стартапера и из документа
#     * причесывает инфу про бизнес модель и ценообразование
#     * ЧТО ПРО ТРЕКШН И ФИНАНСЫ?
#     * причесывает инфу про команду и борд
#     * Причесывает инфу про инвестиционный раунд
#     * причесывает инфу про роадмап
#     * причесывает инфу про контакты
# * tech
#     * Парсер по документу со стартапами (или поисковик конкурентов)
#
# Дополнительно:
# * ГПТ или ГПТ4
#     * ЧатГПТ перформулирует краткое описание стартапа в соответствии с принципами YComb
#     * ГПТ генерирует название по описанию
#     * Проработать проблему со стартапером с помощью чатгпт в виде интерактинвого диалога
#     * ГПТ4 занимается сбором и анализом инфы про рынок TOM SOM и тд
#     * ГПТ4 находит конкурентов в интернете и их же анализирует
#     * ГПТ4 либо ищет инфу про бизнес модель и ценообразование на сайте, либо предлагает варианты
#     * ГПТ4 сам ищет инфу про трекшн и финансы на сайте, либо ведет интерактивный диалог
#     * ГПТ4 общается со стартапером про команду + борд и в интерактивном режиме делаем в соответсвии с YComb
# * tech
#     *

# %% [markdown]
# **Все еще остались вопросы:**

# %% [markdown]
# **Супер дополнительно**:
# * Использовать агентов вместо цепочек.
